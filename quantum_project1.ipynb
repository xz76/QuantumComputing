# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, Aer, execute  
 # Qiskit allows us to make beautiful plots 
from qiskit.visualization import plot_histogram     
from numpy import pi

# %%
qreg_q = QuantumRegister(1, 'q')
creg_c = ClassicalRegister(1, 'measure')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.measure(qreg_q[0], creg_c[0])

simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
# Grab results from the job
result = job.result()
counts = result.get_counts(compiled_circuit)
circuit.draw(output="mpl")

# %%
print("\nTotal count for 0 and 1 are:", counts)
plot_histogram(counts)
# Out:
# Total count for 0 and 1 are: {'0': 514, '1': 486}

# %%
qreg_q = QuantumRegister(1, 'q')
creg_c = ClassicalRegister(1, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.ry(pi / 4, qreg_q[0])
circuit.measure(qreg_q[0], creg_c[0])
simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
# Grab results from the job
result = job.result()
counts = result.get_counts(compiled_circuit)
circuit.draw(output="mpl")

# %%
print("\nTotal count for 0 and 1 are:", counts)
plot_histogram(counts)
# Out:
# Total count for 0 and 1 are: {'1': 163, '0': 837}

# %%
qreg_q = QuantumRegister(1, 'q')
creg_c = ClassicalRegister(1, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.ry(pi / 4, qreg_q[0])
circuit.x(qreg_q[0])
circuit.measure(qreg_q[0], creg_c[0])

simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
# Grab results from the job
result = job.result()
counts = result.get_counts(compiled_circuit)
circuit.draw(output="mpl")

# %%
print("\nTotal count for 0 and 1 are:", counts)
plot_histogram(counts)
# Out:
# Total count for 0 and 1 are: {'0': 133, '1': 867}

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])

simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
# Grab results from the job
result = job.result()
counts = result.get_counts(compiled_circuit)
circuit.draw(output="mpl")

# %%
print("\nTotal count for 00 and 11 are:", counts)
plot_histogram(counts)
# Out:
# Total count for 00 and 11 are: {'00': 508, '11': 492}

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[0])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
# @columns [0,1,2,3,4]

simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
# Grab results from the job
result = job.result()
counts = result.get_counts(compiled_circuit)
circuit.draw(output="mpl")

# %%
print("\nTotal count for 00 and 11 are:", counts)
plot_histogram(counts)
# Out:
# Total count for 00 and 11 are: {'00': 506, '11': 494}

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.x(qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
# @columns [0,0,1,4,5]
simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
# Grab results from the job
result = job.result()
counts = result.get_counts(compiled_circuit)
circuit.draw(output="mpl")

# %%
print("\nTotal count for 01 and 10 are:", counts)
plot_histogram(counts)
# Out:
# Total count for 01 and 10 are: {'01': 498, '10': 502}

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
# @columns [0,0,1,2,4,5]

simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
# Grab results from the job
result = job.result()
counts = result.get_counts(compiled_circuit)
circuit.draw(output="mpl")

# %%
print("\nTotal count for 01 and 10 are:", counts)
plot_histogram(counts)
# Out:
# Total count for 01 and 10 are: {'01': 499, '10': 501}

# %%
qreg_q = QuantumRegister(3, 'q')
creg_c = ClassicalRegister(3, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[2])
circuit.h(qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[2], creg_c[2])
# @columns [0,1,2,3,4,5,6]

simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
# Grab results from the job
result = job.result()
counts = result.get_counts(compiled_circuit)
circuit.draw(output="mpl")

# %%
print("\nTotal count for 00 and 11 are:", counts)
plot_histogram(counts)
# Out:
# Total count for 00 and 11 are: {'111': 242, '101': 241, '010': 241, '000': 276}

# %%
qreg_q = QuantumRegister(3, 'q')
creg_c = ClassicalRegister(3, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[2])
circuit.h(qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[2], creg_c[2])
# @columns [0,1,2,3,4,5,6]

simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
# Grab results from the job
result = job.result()
counts = result.get_counts(compiled_circuit)
circuit.draw(output="mpl")
print(counts)
plot_histogram(counts)
# Out:
# {'111': 517, '101': 483}

# %%
qreg_q = QuantumRegister(3, 'q')
creg_c = ClassicalRegister(3, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.x(qreg_q[1])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[2])
circuit.h(qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[2], creg_c[2])
# @columns [0,1,2,4,5,6,7]

simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
# Grab results from the job
result = job.result()
counts = result.get_counts(compiled_circuit)
circuit.draw(output="mpl")
print(counts)
plot_histogram(counts)
# Out:
# {'111': 243, '101': 234, '000': 231, '010': 292}
